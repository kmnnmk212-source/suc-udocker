# %% [markdown]
# https://github.com/indigo-dc/udocker/releases

# %%
# %%bash
# wget https://github.com/indigo-dc/udocker/releases/download/1.3.17/udocker-1.3.17.tar.gz
# tar zxvf udocker-1.3.17.tar.gz
# export PATH=`pwd`/udocker-1.3.17/udocker:$PATH
# Out:
# udocker-1.3.17/
# udocker-1.3.17/udocker/
# udocker-1.3.17/udocker/tools.py
# udocker-1.3.17/udocker/__init__.py
# udocker-1.3.17/udocker/localfile.py
# udocker-1.3.17/udocker/msg.py
# udocker-1.3.17/udocker/container/
# udocker-1.3.17/udocker/container/__init__.py
# udocker-1.3.17/udocker/container/structure.py
# udocker-1.3.17/udocker/container/localrepo.py
# udocker-1.3.17/udocker/commonlocalfile.py
# udocker-1.3.17/udocker/cmdparser.py
# udocker-1.3.17/udocker/engine/
# udocker-1.3.17/udocker/engine/__init__.py
# udocker-1.3.17/udocker/engine/nvidia.py
# udocker-1.3.17/udocker/engine/base.py
# udocker-1.3.17/udocker/engine/proot.py
# udocker-1.3.17/udocker/engine/fakechroot.py
# udocker-1.3.17/udocker/engine/runc.py
# udocker-1.3.17/udocker/engine/execmode.py
# udocker-1.3.17/udocker/engine/singularity.py
# udocker-1.3.17/udocker/docker.py
# udocker-1.3.17/udocker/utils/
# udocker-1.3.17/udocker/utils/__init__.py
# udocker-1.3.17/udocker/utils/mountpoint.py
# ...

# %%
# %%bash
# udocker --allow-root --help
# udocker --allow-root install
# Out:
# bash: line 1: udocker: command not found
# bash: line 2: udocker: command not found
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipython-input-2082805322.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('bash', '', 'udocker --allow-root --help\nudocker --allow-root install\n')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     274     if line and not cell:
#     275       cell = ' '
# --> 276     return super().run_cell_magic(magic_name, line, cell)
#     277
#     278
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
# ...

# %%
--allow-root

# %%
# %%bash
# udocker --allow-root --help
# Out:
# bash: line 1: udocker: command not found
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipython-input-4041786754.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('bash', '', 'udocker --allow-root --help\n')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     274     if line and not cell:
#     275       cell = ' '
# --> 276     return super().run_cell_magic(magic_name, line, cell)
#     277
#     278
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# ...

# %% [markdown]
# https://github.com/indigo-dc/udocker/releases
#
#
#
# ### https://github.com/indigo-dc/udocker

# %%
# !udocker-1.3.17/udocker/udocker --allow-root -h
# Out:
# Info: creating repo: /root/.udocker
#
# Syntax:
#   udocker  [general_options] <command>  [command_options]  <command_args>
#
#   udocker [-h|--help|help]        :Display this help and exits
#   udocker [-V|--version|version]  :Display udocker and tarball version and exits
#
# General options common to all commands must appear before the command:
#   -D, --debug                   :Debug
#   -q, --quiet                   :Less verbosity
#   --insecure                    :Allow insecure non authenticated https
#   --repo=<directory>            :Use repository at directory
#   --allow-root                  :Allow execution by root NOT recommended
#   --config=<conf_file>          :Use configuration <conf_file>
#
# Commands:
#   --help [command]              :Command specific help
#   showconf                      :Print all configuration options
#
#   search <repo/expression>      :Search dockerhub for container images
# ...

# %%
udocker setup --help

# %%
# !udocker-1.3.17/udocker/udocker  --allow-root setup --help
# Out:
#         setup: change container execution settings
#         setup [options] <container-id>
#         --execmode=<mode>       :select execution mode from below
#         --force                 :force setup change
#         --purge                 :clean mountpoints and files created by udocker
#         --fixperm               :attempt to fix file permissions
#         --nvidia                :add NVIDIA libraries and binaries
#
#         <mode> is one of the following execution modes:
#         P1: proot accelerated mode using seccomp filtering (default)
#         P2: proot accelerated mode disabled
#         F1: fakechroot starting executables via direct loader invocation
#         F2: like F1 plus protected environment and modified ld.so
#         F3: fakechroot plus patching of elf headers in binaries and libs
#         F4: like F3 plus support for newly created executables via
#             dynamic patching of elf headers in binaries and libs
# ...
